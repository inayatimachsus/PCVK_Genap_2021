# %% [markdown]
# <a href="https://colab.research.google.com/github/inayatimachsus/PCVK_Genap_2021/blob/main/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive


#accessing  My Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/PCVK/Images/koceng.jpg')
plt.imshow(img)     #perhatikan hasilnya adalah citra dengan channel warna BGR

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)      #konversi channel BGR -> RGB
plt.imshow(img3)

# %%
# Menampilkan citra Grayscale
img_gray = cv.imread('/content/drive/MyDrive/PCVK/Images/koceng.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
# Menampilkan colormap dnegan warna gray
plt.imshow(img_gray, cmap='gray')

# %%
# Menampilkan colormap dengan warna magma
plt.imshow(img_gray, cmap='magma')

# %%
# Resize
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %%
# Ukuran lebih besar dan terbalik
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

#simpa File image
#cv.imwrite('/content/drive/MyDrive/PCVK/Images/madrill2.tiff',img5)

#tampilkan plot dengan ukuran canvas yg lebih besar
fig = plt.figure(figsize=(10,10))     #ubah2 ukuran (10,10) sesuai kebutuhan
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %%
#perhatikan koordinator titik2 pt1 dan ot2
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %%
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2=np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2)) #nilai 2 untuk menunjukkan bahwa tiap titik dibuat 3 channel yg mewakili R,G,dan B
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# **PERTANYAAN**
#
# 1.   Apakah perbedaan gambar yang ditampilkan tanpa dan dengan matplotlib?
#
#       **Jawaban :**
#
#       Dengan menggunakan matplotlib gambar akan tampil dengan ukuran sumbu y dan sumbu x yang dapat digunakan utnuk mengetahui ukuran panjang dan lebar image, sedangkan tanpa matplotlib gambar yang tampil hanya file image nya saja.
#
#
#
# 2.   Apakah perbedaan dan pengaruhnya pembuatan black image antara tipe data int16 dan int32?
#
#       **Jawaban :**
# *   Int16 Ini adalah FCL type. Dalam C#, pendek dipetakan ke Int16. Ini adalah jenis nilai dan mewakili Sistem.Int16 struct.Hal ini ditandatangani dan membutuhkan 16 bit.Memiliki minimal -32768 dan maksimum +32767 nilai.
# *   Int32Ini adalah FCL type.Dalam C#, int dipetakan ke Int32.Ini adalah jenis nilai dan mewakili Sistem.Int32 struct.Hal ini ditandatangani dan membutuhkan 32 bit Memiliki minimal -2147483648 dan maksimum +2147483647 nilai.
#
#
# 3. Jelaskan tentang angka-angka yang terdapat pada reshape((-1,1,2))
# ![WhatsApp Image 2021-02-26 at 12.42.10 PM.jpeg](data:image/jpeg;base64,...)
#
#       **Jawaban :**
#
#       Untuk mengatur tata letak ukuran array tersebut.
#
#
# 4. Apakah kegunaan “google.colab.patches import cv2_imshow” pada potongan kode berikut
# ![2.jpg](data:image/jpeg;base64,...)
#
#       **Jawaban :**
#
#       Menambahkan satu patches karena cv.imshow tidak berjalan di Google Colab.
#
#
# 5. Apakah kegunaan “skimage import io” pada potongan kode soal nomor 4
#
#       **Jawaban :**
#
#       Menyediakan fungsi konversi untuk gambar.

# %%
img_rg = img
img_rg[:,:,2] = 0
plt.imshow(img_rg)

# %%
img_gb = img
# img_gb[:,:,0] = 0
plt.imshow(img_gb)

# %%
img_arr = img[10:100,10:100]
plt.imshow(img_arr)

# %%
plt.imshow(img[5:30])

# %%
img_k = cv.cvtColor(img,cv.COLOR_BGR2RGB)

cv.rectangle(img_k, pt1=(0,100), pt2=(100,175), color=(255,255,255), thickness=3)
cv.rectangle(img_k, pt1=(100,0), pt2=(175,100), color=(255,255,255), thickness=3)
cv.rectangle(img_k, pt1=(50,50), pt2=(150,150), color=(255,255,255), thickness=3)
cv.rectangle(img_k, pt1=(75,125), pt2=(260,180), color=(255,255,255), thickness=3)
cv.rectangle(img_k, pt1=(225,10), pt2=(275,75), color=(255,255,255), thickness=3)

plt.imshow(img_k)

# %%
img_t = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB), 0)
plt.imshow(img_t)

# %%
imgt = img2

cv.rectangle(imgt,pt1=(35,30),pt2=(150,135),color=(255,255,255), thickness=5)
cv.circle(imgt,center=(90,87),radius=50,color=(255,0,0), thickness=5)

plt.imshow(imgt)

# %%
cv.rectangle(imgt,pt1=(0,125),pt2=(60,180),color=(0,0,255),thickness=10)
plt.imshow(imgt)
